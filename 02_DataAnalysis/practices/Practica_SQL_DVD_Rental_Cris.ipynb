# %%
'''
1. **¿Tenemos actores en la tabla de actores que comparten el nombre completo y, en caso afirmativo, muestran esos nombres compartidos?**

Para responder a esa pregunta, primero necesitamos saber si tenemos actores en la tabla de actores que comparten sus nombres completos. Entonces comenzar contando la cantidad de actores que comparten sus nombres completos.
'''

# %%
import psycopg2

# Connect to an existing database HEROKY _ nuestro nombre
conn = psycopg2.connect(
    host="ec2-54-73-58-75.eu-west-1.compute.amazonaws.com",
    database="d6jbvjn3b9tsce",
    user="mayknebhombpsq",
    password="dbc24635f5cbe1851f07d823eeada249c8751415ee900274b96110652bc94874",
    port=5432)

query = """
SELECT CONCAT(first_name,' ', last_name) Nombre_completo, COUNT('Nombre_completo')
FROM actor
GROUP BY 1
HAVING COUNT('Nombre_completo') >1;
"""

#Creating a cursor object using the cursor() method
cursor = conn.cursor()
#Retrieving data
cursor.execute(query)
#Fetching 1st row from the table
#result = cursor.fetchone();
#print(result)
#Fetching 1st row from the table
result = cursor.fetchall();
result
# Out:
# [('Susan Davis', 2)]

# %%
'''
2. **Muestra los nombres de los clientes que comparten la misma dirección (por ejemplo, esposo y esposa).**

Para responder a esta pregunta, debemos buscar más de un cliente que tenga el mismo address_id pero diferentes customer_ids. Eso significa que haremos JOIN a la tabla de clientes para sí mismo (*autounión*).
'''

# %%
import psycopg2

# Connect to an existing database HEROKY _ nuestro nombre
conn = psycopg2.connect(
    host="ec2-54-73-58-75.eu-west-1.compute.amazonaws.com",
    database="d6jbvjn3b9tsce",
    user="mayknebhombpsq",
    password="dbc24635f5cbe1851f07d823eeada249c8751415ee900274b96110652bc94874",
    port=5432)

query = """
SELECT
	c1.first_name,
	c1.last_name,
	c2.first_name,
	c2.last_name
FROM
	customer as c1
	join
	customer as c2
ON c1.customer_id <> c2.customer_id AND
	c1.address_id = c2.address_id
"""

#Creating a cursor object using the cursor() method
cursor = conn.cursor()
#Retrieving data
cursor.execute(query)
#Fetching 1st row from the table
#result = cursor.fetchone();
#print(result)
#Fetching 1st row from the table
result = cursor.fetchall();
result
# Out:
# []

# %%
import psycopg2

# Connect to an existing database HEROKY _ nuestro nombre
conn = psycopg2.connect(
    host="ec2-54-73-58-75.eu-west-1.compute.amazonaws.com",
    database="d6jbvjn3b9tsce",
    user="mayknebhombpsq",
    password="dbc24635f5cbe1851f07d823eeada249c8751415ee900274b96110652bc94874",
    port=5432)

query = """
SELECT
  address_id,
  COUNT(address_id)
FROM
	customer
GROUP BY address_id
ORDER BY COUNT(address_id) DESC
LIMIT 3;
"""

#Creating a cursor object using the cursor() method
cursor = conn.cursor()
#Retrieving data
cursor.execute(query)
#Fetching 1st row from the table
#result = cursor.fetchone();
#print(result)
#Fetching 1st row from the table
result = cursor.fetchall();
result
# Out:
# [(6, 1), (7, 1), (5, 1)]

# %%
'''3. **Muestra el monto total pagado por todos los clientes en la tabla de pagos.**

Utilizar aquí la función agregada **SUM()** en la columna de monto de la tabla de pagos.'''

# %%
import psycopg2

# Connect to an existing database HEROKY _ nuestro nombre
conn = psycopg2.connect(
    host="ec2-54-73-58-75.eu-west-1.compute.amazonaws.com",
    database="d6jbvjn3b9tsce",
    user="mayknebhombpsq",
    password="dbc24635f5cbe1851f07d823eeada249c8751415ee900274b96110652bc94874",
    port=5432)

query = """
SELECT
  SUM(amount) as Suma
FROM
	payment
"""

#Creating a cursor object using the cursor() method
cursor = conn.cursor()
#Retrieving data
cursor.execute(query)
#Fetching 1st row from the table
#result = cursor.fetchone();
#print(result)
#Fetching 1st row from the table
result = cursor.fetchall();
result

#import pandas as pd
#df = pd.DataFrame(result)
#print (df[0])
# Out:
# [(Decimal('61312.04'),)]

# %%
print(result[0][0])
# Out:
# 61312.04

# %%
#4. **Muestre el monto total pagado por cada cliente en la tabla de pagos.**

# %%
import psycopg2

# Connect to an existing database HEROKY _ nuestro nombre
conn = psycopg2.connect(
    host="ec2-54-73-58-75.eu-west-1.compute.amazonaws.com",
    database="d6jbvjn3b9tsce",
    user="mayknebhombpsq",
    password="dbc24635f5cbe1851f07d823eeada249c8751415ee900274b96110652bc94874",
    port=5432)

query = """
SELECT
  customer.first_name, customer.last_name, SUM(payment.amount)
FROM
	payment
RIGHT JOIN
 customer
ON
  customer.customer_id = payment.customer_id
GROUP BY
  customer.customer_id;
"""

#Creating a cursor object using the cursor() method
cursor = conn.cursor()
#Retrieving data
cursor.execute(query)
#Fetching 1st row from the table
#result = cursor.fetchone();
#print(result)
#Fetching 1st row from the table
result = cursor.fetchall()
result
# Out:
# [('Vivian', 'Ruiz', Decimal('80.80')),
#  ('Wanda', 'Patterson', Decimal('137.72')),
#  ('Dan', 'Paine', Decimal('106.79')),
#  ('Priscilla', 'Lowe', Decimal('130.72')),
#  ('Guy', 'Brownlee', Decimal('151.69')),
#  ('Alice', 'Stewart', Decimal('123.70')),
#  ('Chris', 'Brothers', Decimal('77.80')),
#  ('Kay', 'Caldwell', Decimal('65.87')),
#  ('Christina', 'Ramirez', Decimal('75.83')),
#  ('Yolanda', 'Weaver', Decimal('102.75')),
#  ('Juan', 'Fraley', Decimal('63.79')),
#  ('Mathew', 'Bolin', Decimal('84.80')),
#  ('Dwayne', 'Olvera', Decimal('95.80')),
#  ('Billie', 'Horton', Decimal('71.79')),
#  ('Kyle', 'Spurlock', Decimal('109.71')),
#  ('Nathan', 'Runyon', Decimal('121.69')),
#  ('June', 'Carroll', Decimal('151.68')),
#  ('Morris', 'Mccarter', Decimal('135.68')),
#  ('Christopher', 'Greco', Decimal('113.75')),
#  ('Misty', 'Lambert', Decimal('102.78')),
#  ('Raul', 'Fortier', Decimal('86.82')),
#  ('Penny', 'Neal', Decimal('56.84')),
# ...

# %%
#5. **¿Cuál es el pago total más alto realizado?**

# %%
import psycopg2

# Connect to an existing database HEROKY _ nuestro nombre
conn = psycopg2.connect(
    host="ec2-54-73-58-75.eu-west-1.compute.amazonaws.com",
    database="d6jbvjn3b9tsce",
    user="mayknebhombpsq",
    password="dbc24635f5cbe1851f07d823eeada249c8751415ee900274b96110652bc94874",
    port=5432)

query = """
SELECT
  payment_id, amount 
FROM
  payment
order by 2 desc
limit 15;
"""

#Creating a cursor object using the cursor() method
cursor = conn.cursor()
#Retrieving data
cursor.execute(query)
#Fetching 1st row from the table
#result = cursor.fetchone();
#print(result)
#Fetching 1st row from the table
result = cursor.fetchall();
result
# Out:
# [(28814, Decimal('11.99')),
#  (24553, Decimal('11.99')),
#  (23757, Decimal('11.99')),
#  (28799, Decimal('11.99')),
#  (29136, Decimal('11.99')),
#  (24866, Decimal('11.99')),
#  (20403, Decimal('11.99')),
#  (22650, Decimal('11.99')),
#  (19481, Decimal('10.99')),
#  (18153, Decimal('10.99')),
#  (18640, Decimal('10.99')),
#  (18576, Decimal('10.99')),
#  (18035, Decimal('10.99')),
#  (19336, Decimal('10.99')),
#  (19642, Decimal('10.99'))]

# %%
#**6. ¿Cuál es el nombre del cliente que realizó los pagos totales más altos?**

# %%
import psycopg2

# Connect to an existing database HEROKY _ nuestro nombre
conn = psycopg2.connect(
    host="ec2-54-73-58-75.eu-west-1.compute.amazonaws.com",
    database="d6jbvjn3b9tsce",
    user="mayknebhombpsq",
    password="dbc24635f5cbe1851f07d823eeada249c8751415ee900274b96110652bc94874",
    port=5432)

query = """
SELECT
 payment.customer_id, customer.first_name, payment.amount 
FROM
  payment
JOIN
  rental
ON
WHERE
  amount = 
  (SELECT
    MAX(amount)
    FROM
    payment
  );
"""

#Creating a cursor object using the cursor() method
cursor = conn.cursor()
#Retrieving data
cursor.execute(query)
#Fetching 1st row from the table
#result = cursor.fetchone();
#print(result)
#Fetching 1st row from the table
result = cursor.fetchall();
result
# Out:
# [(362, Decimal('11.99')),
#  (204, Decimal('11.99')),
#  (116, Decimal('11.99')),
#  (195, Decimal('11.99')),
#  (237, Decimal('11.99')),
#  (591, Decimal('11.99')),
#  (592, Decimal('11.99')),
#  (13, Decimal('11.99'))]

# %%
import psycopg2

# Connect to an existing database HEROKY _ nuestro nombre
conn = psycopg2.connect(
    host="ec2-54-73-58-75.eu-west-1.compute.amazonaws.com",
    database="d6jbvjn3b9tsce",
    user="mayknebhombpsq",
    password="dbc24635f5cbe1851f07d823eeada249c8751415ee900274b96110652bc94874",
    port=5432)

query = """
SELECT
 customer.first_name, customer.last_name, payment.amount 
FROM
  payment
JOIN
  customer
ON
  payment.customer_id=customer.customer_id
WHERE
  amount = 
  (SELECT
    MAX(payment.amount)
    FROM
    payment
  );
"""

#Creating a cursor object using the cursor() method
cursor = conn.cursor()
#Retrieving data
cursor.execute(query)
#Fetching 1st row from the table
#result = cursor.fetchone();
#print(result)
#Fetching 1st row from the table
result = cursor.fetchall();
result
# Out:
# [('Nicholas', 'Barfield', Decimal('11.99')),
#  ('Rosemary', 'Schmidt', Decimal('11.99')),
#  ('Victoria', 'Gibson', Decimal('11.99')),
#  ('Vanessa', 'Sims', Decimal('11.99')),
#  ('Tanya', 'Gilbert', Decimal('11.99')),
#  ('Kent', 'Arsenault', Decimal('11.99')),
#  ('Terrance', 'Roush', Decimal('11.99')),
#  ('Karen', 'Jackson', Decimal('11.99'))]

# %%
#**7. ¿Cuáles son las películas que más se alquilaron?**

# %%
import psycopg2

# Connect to an existing database HEROKY _ nuestro nombre
conn = psycopg2.connect(
    host="ec2-54-73-58-75.eu-west-1.compute.amazonaws.com",
    database="d6jbvjn3b9tsce",
    user="mayknebhombpsq",
    password="dbc24635f5cbe1851f07d823eeada249c8751415ee900274b96110652bc94874",
    port=5432)

query = """
SELECT
 film.title, COUNT(rental.rental_id )
FROM
  rental
JOIN
  inventory
ON
  rental.inventory_id = inventory.inventory_id
JOIN
  film
ON
  film.film_id = inventory.film_id
GROUP BY
  1
ORDER BY 
  2 DESC
LIMIT (10);
"""

#Creating a cursor object using the cursor() method
cursor = conn.cursor()
#Retrieving data
cursor.execute(query)
#Fetching 1st row from the table
#result = cursor.fetchone();
#print(result)
#Fetching 1st row from the table
result = cursor.fetchall();
result
# Out:
# [('Bucket Brotherhood', 34),
#  ('Rocketeer Mother', 33),
#  ('Juggler Hardly', 32),
#  ('Ridgemont Submarine', 32),
#  ('Grit Clockwork', 32),
#  ('Forward Temple', 32),
#  ('Scalawag Duck', 32),
#  ('Apache Divine', 31),
#  ('Goodfellas Salute', 31),
#  ('Rush Goodfellas', 31)]

# %%
import psycopg2

# Connect to an existing database HEROKY _ nuestro nombre
conn = psycopg2.connect(
    host="ec2-54-73-58-75.eu-west-1.compute.amazonaws.com",
    database="d6jbvjn3b9tsce",
    user="mayknebhombpsq",
    password="dbc24635f5cbe1851f07d823eeada249c8751415ee900274b96110652bc94874",
    port=5432)

query = """
SELECT
 inventory.film_id, COUNT(rental.rental_id )
FROM
  rental
JOIN
  inventory
ON
  rental.inventory_id = inventory.inventory_id
GROUP BY
  1
ORDER BY 
  2 DESC
LIMIT (10);
"""

#Creating a cursor object using the cursor() method
cursor = conn.cursor()
#Retrieving data
cursor.execute(query)
#Fetching 1st row from the table
#result = cursor.fetchone();
#print(result)
#Fetching 1st row from the table
result = cursor.fetchall();
result
# Out:
# [(103, 34),
#  (738, 33),
#  (730, 32),
#  (489, 32),
#  (331, 32),
#  (767, 32),
#  (382, 32),
#  (735, 31),
#  (418, 31),
#  (891, 31),
#  (31, 31)]

# %%
#**8. Qué películas se han alquilado hasta ahora.**

# %%
import psycopg2

# Connect to an existing database HEROKY _ nuestro nombre
conn = psycopg2.connect(
    host="ec2-54-73-58-75.eu-west-1.compute.amazonaws.com",
    database="d6jbvjn3b9tsce",
    user="mayknebhombpsq",
    password="dbc24635f5cbe1851f07d823eeada249c8751415ee900274b96110652bc94874",
    port=5432)

query = """
SELECT
 film.title, COUNT(rental.rental_id)
FROM
  film
JOIN
  inventory
ON
  film.film_id = inventory.film_id
JOIN
  rental
ON
  rental.inventory_id = inventory.inventory_id
GROUP BY
  1
ORDER BY
2 ASC;
"""

#Creating a cursor object using the cursor() method
cursor = conn.cursor()
#Retrieving data
cursor.execute(query)
#Fetching 1st row from the table
#result = cursor.fetchone();
#print(result)
#Fetching 1st row from the table
result = cursor.fetchall();
print(result)
print(len(result))
# Out:
# [('Mixed Doors', 4), ('Train Bunch', 4), ('Hardly Robbers', 4), ('Mannequin Worst', 5), ('Braveheart Human', 5), ('Bunch Minds', 5), ('Private Drop', 5), ('Traffic Hobbit', 5), ('Mussolini Spoilers', 5), ('Seven Swarm', 5), ('Full Flatliners', 5), ('Fever Empire', 5), ('Glory Tracy', 5), ('Informer Double', 5), ('Conspiracy Spirit', 5), ('Freedom Cleopatra', 5), ('Hunter Alter', 5), ('Graceland Dynamite', 6), ('Terminator Club', 6), ('Extraordinary Conquerer', 6), ('Oklahoma Jumanji', 6), ('Rushmore Mermaid', 6), ('Tequila Past', 6), ('School Jacket', 6), ('Happiness United', 6), ('Frontier Cabin', 6), ('Sling Luke', 6), ('Apocalypse Flamingos', 6), ('Watership Frontier', 6), ('Ladybugs Armageddon', 6), ('Bed Highball', 6), ('Simon North', 6), ('Texas Watch', 6), ('Bubble Grosse', 6), ('Jersey Sassy', 6), ('Haunted Antitrust', 6), ('Wild Apollo', 6), ('Duck Racer', 6), ('Comancheros Enemy', 6), ('Italian African', 6), ('Warlock Werewolf', 6), ('Desperate Trainspotting', 6), ('Killer 
# ...

# %%
#**9. Qué películas no se han alquilado hasta ahora.**

# %%
import psycopg2

# Connect to an existing database HEROKY _ nuestro nombre
conn = psycopg2.connect(
    host="ec2-54-73-58-75.eu-west-1.compute.amazonaws.com",
    database="d6jbvjn3b9tsce",
    user="mayknebhombpsq",
    password="dbc24635f5cbe1851f07d823eeada249c8751415ee900274b96110652bc94874",
    port=5432)

query = """
SELECT
 film.title, COUNT(rental.rental_id ) as num_rentals
FROM
  film
FULL JOIN
  inventory
ON
  film.film_id = inventory.film_id
FULL JOIN
  rental
ON
  rental.inventory_id = inventory.inventory_id
GROUP BY
  1
HAVING COUNT(rental.rental_id)=0
ORDER BY 1
  ;
"""

#Creating a cursor object using the cursor() method
cursor = conn.cursor()
#Retrieving data
cursor.execute(query)
#Fetching 1st row from the table
#result = cursor.fetchone();
#print(result)
#Fetching 1st row from the table
result = cursor.fetchall();
print(result)
print(len(result))
# Out:
# [('Alice Fantasia', 0), ('Apollo Teen', 0), ('Argonauts Town', 0), ('Ark Ridgemont', 0), ('Arsenic Independence', 0), ('Boondock Ballroom', 0), ('Butch Panther', 0), ('Catch Amistad', 0), ('Chinatown Gladiator', 0), ('Chocolate Duck', 0), ('Commandments Express', 0), ('Crossing Divorce', 0), ('Crowds Telemark', 0), ('Crystal Breaking', 0), ('Dazed Punk', 0), ('Deliverance Mulholland', 0), ('Firehouse Vietnam', 0), ('Floats Garden', 0), ('Frankenstein Stranger', 0), ('Gladiator Westward', 0), ('Gump Date', 0), ('Hate Handicap', 0), ('Hocus Frida', 0), ('Kentuckian Giant', 0), ('Kill Brotherhood', 0), ('Muppet Mile', 0), ('Order Betrayed', 0), ('Pearl Destiny', 0), ('Perdition Fargo', 0), ('Psycho Shrunk', 0), ('Raiders Antitrust', 0), ('Rainbow Shock', 0), ('Roof Champion', 0), ('Sister Freddy', 0), ('Sky Miracle', 0), ('Suicides Silence', 0), ('Tadpole Park', 0), ('Treasure Command', 0), ('Villain Desperate', 0), ('Volume House', 0), ('Wake Jaws', 0), ('Walls Artist', 0)]
# 42

# %%
#He probado con la opción siguiente, pero hay diferencia en una película: 'Academy Dinosaur' que no debería aparecer, y aparece porque aunque sí que tiene registros con 'rental_date', existe un registro en el que el 'rental_date' está vacío.

# %%
import psycopg2

# Connect to an existing database HEROKY _ nuestro nombre
conn = psycopg2.connect(
    host="ec2-54-73-58-75.eu-west-1.compute.amazonaws.com",
    database="d6jbvjn3b9tsce",
    user="mayknebhombpsq",
    password="dbc24635f5cbe1851f07d823eeada249c8751415ee900274b96110652bc94874",
    port=5432)

query = """
select distinct film.title
from film
FULL join
inventory
on
film.film_id = inventory.film_id
FULL Join
rental
on
rental.inventory_id = inventory.inventory_id
where rental_date is NULL
;
"""

#Creating a cursor object using the cursor() method
cursor = conn.cursor()
#Retrieving data
cursor.execute(query)
#Fetching 1st row from the table
#result = cursor.fetchone();
#print(result)
#Fetching 1st row from the table
result = cursor.fetchall()
print(result)
print(len(result))
# Out:
# [('Academy Dinosaur',), ('Alice Fantasia',), ('Apollo Teen',), ('Argonauts Town',), ('Ark Ridgemont',), ('Arsenic Independence',), ('Boondock Ballroom',), ('Butch Panther',), ('Catch Amistad',), ('Chinatown Gladiator',), ('Chocolate Duck',), ('Commandments Express',), ('Crossing Divorce',), ('Crowds Telemark',), ('Crystal Breaking',), ('Dazed Punk',), ('Deliverance Mulholland',), ('Firehouse Vietnam',), ('Floats Garden',), ('Frankenstein Stranger',), ('Gladiator Westward',), ('Gump Date',), ('Hate Handicap',), ('Hocus Frida',), ('Kentuckian Giant',), ('Kill Brotherhood',), ('Muppet Mile',), ('Order Betrayed',), ('Pearl Destiny',), ('Perdition Fargo',), ('Psycho Shrunk',), ('Raiders Antitrust',), ('Rainbow Shock',), ('Roof Champion',), ('Sister Freddy',), ('Sky Miracle',), ('Suicides Silence',), ('Tadpole Park',), ('Treasure Command',), ('Villain Desperate',), ('Volume House',), ('Wake Jaws',), ('Walls Artist',)]
# 43

# %%
10. #**Qué clientes no han alquilado ninguna película hasta ahora.**

# %%
import psycopg2

# Connect to an existing database HEROKY _ nuestro nombre
conn = psycopg2.connect(
    host="ec2-54-73-58-75.eu-west-1.compute.amazonaws.com",
    database="d6jbvjn3b9tsce",
    user="mayknebhombpsq",
    password="dbc24635f5cbe1851f07d823eeada249c8751415ee900274b96110652bc94874",
    port=5432)

query = """
SELECT
 customer.customer_id, COUNT(rental.rental_id)
FROM
  customer
LEFT JOIN
  rental
ON
  customer.customer_id = rental.customer_id
GROUP BY
  1
HAVING COUNT(rental.rental_id)=0
  ;
"""

#Creating a cursor object using the cursor() method
cursor = conn.cursor()
#Retrieving data
cursor.execute(query)
#Fetching 1st row from the table
#result = cursor.fetchone();
#print(result)
#Fetching 1st row from the table
result = cursor.fetchall();
result
# Out:
# []

# %%
import psycopg2

# Connect to an existing database HEROKY _ nuestro nombre
conn = psycopg2.connect(
    host="ec2-54-73-58-75.eu-west-1.compute.amazonaws.com",
    database="d6jbvjn3b9tsce",
    user="mayknebhombpsq",
    password="dbc24635f5cbe1851f07d823eeada249c8751415ee900274b96110652bc94874",
    port=5432)

query = """
SELECT
 customer.customer_id, COUNT(rental.rental_id)
FROM
  customer
LEFT JOIN
  rental
ON
  customer.customer_id = rental.customer_id
WHERE rental.rental_date IS NULL
GROUP BY
  1
  ;
"""

#Creating a cursor object using the cursor() method
cursor = conn.cursor()
#Retrieving data
cursor.execute(query)
#Fetching 1st row from the table
#result = cursor.fetchone();
#print(result)
#Fetching 1st row from the table
result = cursor.fetchall();
result
# Out:
# []

# %%
import psycopg2

# Connect to an existing database HEROKY _ nuestro nombre
conn = psycopg2.connect(
    host="ec2-54-73-58-75.eu-west-1.compute.amazonaws.com",
    database="d6jbvjn3b9tsce",
    user="mayknebhombpsq",
    password="dbc24635f5cbe1851f07d823eeada249c8751415ee900274b96110652bc94874",
    port=5432)

query = """
SELECT
 customer.customer_id, COUNT(rental.rental_id)
FROM
  customer
LEFT JOIN
  rental
ON
  customer.customer_id = rental.customer_id
GROUP BY
  1
ORDER BY 2 ASC ;
"""

#Creating a cursor object using the cursor() method
cursor = conn.cursor()
#Retrieving data
cursor.execute(query)
#Fetching 1st row from the table
#result = cursor.fetchone();
#print(result)
#Fetching 1st row from the table
result = cursor.fetchall();
result
# Out:
# [(318, 12),
#  (281, 14),
#  (61, 14),
#  (110, 14),
#  (136, 15),
#  (248, 15),
#  (492, 16),
#  (164, 16),
#  (464, 16),
#  (398, 16),
#  (465, 17),
#  (555, 17),
#  (48, 17),
#  (223, 17),
#  (315, 17),
#  (140, 18),
#  (205, 18),
#  (194, 18),
#  (255, 18),
#  (271, 18),
#  (344, 18),
#  (542, 18),
#  (97, 18),
#  (353, 18),
#  (70, 18),
#  (218, 18),
#  (483, 18),
#  (95, 18),
#  (124, 18),
#  (395, 19),
#  (524, 19),
#  (378, 19),
#  (525, 19),
#  (458, 19),
#  (370, 19),
#  (195, 19),
#  (599, 19),
#  (586, 19),
#  (117, 19),
#  (478, 19),
#  (548, 19),
#  (310, 20),
#  (509, 20),
#  (320, 20),
#  (272, 20),
#  (203, 20),
#  (212, 20),
#  (191, 20),
#  (402, 20),
#  (250, 20),
#  (449, 20),
#  (549, 20),
#  (162, 20),
#  (567, 20),
#  (428, 20),
#  (355, 20),
#  (568, 21),
#  (552, 21),
#  (489, 21),
#  (545, 21),
#  (496, 21),
#  (401, 21),
#  (556, 21),
#  (174, 21),
#  (429, 21),
#  (222, 21),
#  (238, 21),
#  (226, 21),
#  (301, 21),
#  (420, 21),
#  (505, 21),
# ...

# %%
#**11. Muestra cada película y la cantidad de veces que se alquila.**

# %%
import psycopg2

# Connect to an existing database HEROKY _ nuestro nombre
conn = psycopg2.connect(
    host="ec2-54-73-58-75.eu-west-1.compute.amazonaws.com",
    database="d6jbvjn3b9tsce",
    user="mayknebhombpsq",
    password="dbc24635f5cbe1851f07d823eeada249c8751415ee900274b96110652bc94874",
    port=5432)

query = """
SELECT
 film.title, COUNT(rental.rental_id) as num_rentals
FROM
  film
JOIN
  inventory
ON
  film.film_id = inventory.film_id
JOIN
  rental
ON
  rental.inventory_id = inventory.inventory_id
GROUP BY
  1
ORDER BY
2 ASC;
"""


#Creating a cursor object using the cursor() method
cursor = conn.cursor()
#Retrieving data
cursor.execute(query)
#Fetching 1st row from the table
#result = cursor.fetchone();
#print(result)
#Fetching 1st row from the table
result = cursor.fetchall();
result
# Out:
# [('Mixed Doors', 4),
#  ('Train Bunch', 4),
#  ('Hardly Robbers', 4),
#  ('Mannequin Worst', 5),
#  ('Braveheart Human', 5),
#  ('Bunch Minds', 5),
#  ('Private Drop', 5),
#  ('Traffic Hobbit', 5),
#  ('Mussolini Spoilers', 5),
#  ('Seven Swarm', 5),
#  ('Full Flatliners', 5),
#  ('Fever Empire', 5),
#  ('Glory Tracy', 5),
#  ('Informer Double', 5),
#  ('Conspiracy Spirit', 5),
#  ('Freedom Cleopatra', 5),
#  ('Hunter Alter', 5),
#  ('Graceland Dynamite', 6),
#  ('Terminator Club', 6),
#  ('Extraordinary Conquerer', 6),
#  ('Oklahoma Jumanji', 6),
#  ('Rushmore Mermaid', 6),
#  ('Tequila Past', 6),
#  ('School Jacket', 6),
#  ('Happiness United', 6),
#  ('Frontier Cabin', 6),
#  ('Sling Luke', 6),
#  ('Apocalypse Flamingos', 6),
#  ('Watership Frontier', 6),
#  ('Ladybugs Armageddon', 6),
#  ('Bed Highball', 6),
#  ('Simon North', 6),
#  ('Texas Watch', 6),
#  ('Bubble Grosse', 6),
#  ('Jersey Sassy', 6),
#  ('Haunted Antitrust', 6),
#  ('Wild Apollo', 6),
#  ('Duck Racer', 6),
# ...

# %%
#**12. Muestra la cantidad de películas en las que actuó cada actor.**

# %%
import psycopg2

# Connect to an existing database HEROKY _ nuestro nombre
conn = psycopg2.connect(
    host="ec2-54-73-58-75.eu-west-1.compute.amazonaws.com",
    database="d6jbvjn3b9tsce",
    user="mayknebhombpsq",
    password="dbc24635f5cbe1851f07d823eeada249c8751415ee900274b96110652bc94874",
    port=5432)

query = """
SELECT
 actor.actor_id, actor.first_name, actor.last_name, COUNT(film_actor.film_id)
FROM
  actor
LEFT JOIN
  film_actor
ON
  film_actor.actor_id = actor.actor_id
GROUP BY
  1
ORDER BY 4 DESC;
"""

#Creating a cursor object using the cursor() method
cursor = conn.cursor()
#Retrieving data
cursor.execute(query)
#Fetching 1st row from the table
#result = cursor.fetchone();
#print(result)
#Fetching 1st row from the table
result = cursor.fetchall();
result
# Out:
# [(107, 'Gina', 'Degeneres', 42),
#  (102, 'Walter', 'Torn', 41),
#  (198, 'Mary', 'Keitel', 40),
#  (181, 'Matthew', 'Carrey', 39),
#  (23, 'Sandra', 'Kilmer', 37),
#  (81, 'Scarlett', 'Damon', 36),
#  (158, 'Vivien', 'Basinger', 35),
#  (60, 'Henry', 'Berry', 35),
#  (144, 'Angela', 'Witherspoon', 35),
#  (37, 'Val', 'Bolger', 35),
#  (106, 'Groucho', 'Dunst', 35),
#  (13, 'Uma', 'Wood', 35),
#  (150, 'Jayne', 'Nolte', 34),
#  (105, 'Sidney', 'Crowe', 34),
#  (65, 'Angela', 'Hudson', 34),
#  (92, 'Kirsten', 'Akroyd', 34),
#  (108, 'Warren', 'Nolte', 34),
#  (27, 'Julia', 'Mcqueen', 33),
#  (117, 'Renee', 'Tracy', 33),
#  (94, 'Kenneth', 'Torn', 33),
#  (139, 'Ewan', 'Gooding', 33),
#  (146, 'Albert', 'Johansson', 33),
#  (111, 'Cameron', 'Zellweger', 33),
#  (101, 'Susan', 'Davis', 33),
#  (90, 'Sean', 'Guiness', 33),
#  (83, 'Ben', 'Willis', 33),
#  (197, 'Reese', 'West', 33),
#  (127, 'Kevin', 'Garland', 33),
#  (187, 'Renee', 'Ball', 33),
#  (26, 'Rip', 'Crawford', 33),
# ...

# %%
#**13. Muestre los nombres de los actores que actuaron en más de 20 películas.**

# %%
import psycopg2

# Connect to an existing database HEROKY _ nuestro nombre
conn = psycopg2.connect(
    host="ec2-54-73-58-75.eu-west-1.compute.amazonaws.com",
    database="d6jbvjn3b9tsce",
    user="mayknebhombpsq",
    password="dbc24635f5cbe1851f07d823eeada249c8751415ee900274b96110652bc94874",
    port=5432)

query = """
SELECT
 actor.actor_id, actor.first_name, actor.last_name, COUNT(film_actor.film_id)
FROM
  actor
LEFT JOIN
  film_actor
ON
  film_actor.actor_id = actor.actor_id
GROUP BY
  1
HAVING COUNT(film_actor.film_id)>20
ORDER BY
  4 DESC;
"""

#Creating a cursor object using the cursor() method
cursor = conn.cursor()
#Retrieving data
cursor.execute(query)
#Fetching 1st row from the table
#result = cursor.fetchone();
#print(result)
#Fetching 1st row from the table
result = cursor.fetchall();
result
# Out:
# [(107, 'Gina', 'Degeneres', 42),
#  (102, 'Walter', 'Torn', 41),
#  (198, 'Mary', 'Keitel', 40),
#  (181, 'Matthew', 'Carrey', 39),
#  (23, 'Sandra', 'Kilmer', 37),
#  (81, 'Scarlett', 'Damon', 36),
#  (60, 'Henry', 'Berry', 35),
#  (37, 'Val', 'Bolger', 35),
#  (144, 'Angela', 'Witherspoon', 35),
#  (106, 'Groucho', 'Dunst', 35),
#  (158, 'Vivien', 'Basinger', 35),
#  (13, 'Uma', 'Wood', 35),
#  (150, 'Jayne', 'Nolte', 34),
#  (108, 'Warren', 'Nolte', 34),
#  (105, 'Sidney', 'Crowe', 34),
#  (92, 'Kirsten', 'Akroyd', 34),
#  (65, 'Angela', 'Hudson', 34),
#  (146, 'Albert', 'Johansson', 33),
#  (90, 'Sean', 'Guiness', 33),
#  (83, 'Ben', 'Willis', 33),
#  (101, 'Susan', 'Davis', 33),
#  (94, 'Kenneth', 'Torn', 33),
#  (139, 'Ewan', 'Gooding', 33),
#  (197, 'Reese', 'West', 33),
#  (127, 'Kevin', 'Garland', 33),
#  (117, 'Renee', 'Tracy', 33),
#  (111, 'Cameron', 'Zellweger', 33),
#  (26, 'Rip', 'Crawford', 33),
#  (187, 'Renee', 'Ball', 33),
#  (27, 'Julia', 'Mcqueen', 33),
# ...

# %%
#**14. ¿Cuántos actores tienen 8 letras solo en sus nombres?**

# %%
import psycopg2

# Connect to an existing database HEROKY _ nuestro nombre
conn = psycopg2.connect(
    host="ec2-54-73-58-75.eu-west-1.compute.amazonaws.com",
    database="d6jbvjn3b9tsce",
    user="mayknebhombpsq",
    password="dbc24635f5cbe1851f07d823eeada249c8751415ee900274b96110652bc94874",
    port=5432)

query = """
SELECT
 first_name, last_name
FROM
  actor
WHERE
  length(first_name)=8;
"""

#Creating a cursor object using the cursor() method
cursor = conn.cursor()
#Retrieving data
cursor.execute(query)
#Fetching 1st row from the table
#result = cursor.fetchone();
#print(result)
#Fetching 1st row from the table
result = cursor.fetchall();
result
# Out:
# [('Penelope', 'Guiness'),
#  ('Jennifer', 'Davis'),
#  ('Penelope', 'Pinkett'),
#  ('Michelle', 'Mcconaughey'),
#  ('Angelina', 'Astaire'),
#  ('Scarlett', 'Damon'),
#  ('Charlize', 'Dench'),
#  ('Penelope', 'Cronyn'),
#  ('Harrison', 'Bale'),
#  ('Penelope', 'Monroe'),
#  ('Julianne', 'Dench'),
#  ('Scarlett', 'Bening'),
#  ('Geoffrey', 'Heston'),
#  ('Humphrey', 'Willis'),
#  ('Laurence', 'Bullock'),
#  ('Humphrey', 'Garland')]

# %%
#**15**.**Para todas las películas clasificadas como "PG", muéstrame la película y la cantidad de veces que se alquiló.**
#Escribir una subconsulta para seleccionar todos los film_ids que se han alquilado hasta ahora. Para eso, se necesita unir tablas de alquiler e inventario en la columna común Inventory_id.

# %%
import psycopg2

# Connect to an existing database HEROKY _ nuestro nombre
conn = psycopg2.connect(
    host="ec2-54-73-58-75.eu-west-1.compute.amazonaws.com",
    database="d6jbvjn3b9tsce",
    user="mayknebhombpsq",
    password="dbc24635f5cbe1851f07d823eeada249c8751415ee900274b96110652bc94874",
    port=5432)

query = """
SELECT
 film.title, COUNT(rental.rental_id) as num_rentals
FROM
  film
FULL JOIN
  inventory
ON
  film.film_id = inventory.film_id
FULL JOIN
  rental
ON
  rental.inventory_id = inventory.inventory_id
WHERE
  rating = 'PG'
GROUP BY
  1
ORDER BY
2 ASC;
"""

#Creating a cursor object using the cursor() method
cursor = conn.cursor()
#Retrieving data
cursor.execute(query)
#Fetching 1st row from the table
#result = cursor.fetchone();
#print(result)
#Fetching 1st row from the table
result = cursor.fetchall()
result
# Out:
# [('Rainbow Shock', 0),
#  ('Muppet Mile', 0),
#  ('Walls Artist', 0),
#  ('Chinatown Gladiator', 0),
#  ('Arsenic Independence', 0),
#  ('Hate Handicap', 0),
#  ('Gladiator Westward', 0),
#  ('Sky Miracle', 0),
#  ('Kentuckian Giant', 0),
#  ('Volume House', 0),
#  ('Tadpole Park', 0),
#  ('Private Drop', 5),
#  ('Full Flatliners', 5),
#  ('Tequila Past', 6),
#  ('Jersey Sassy', 6),
#  ('Oklahoma Jumanji', 6),
#  ('Cowboy Doom', 7),
#  ('Magic Mallrats', 7),
#  ('Treatment Jekyll', 7),
#  ('Mulholland Beast', 7),
#  ('President Bang', 7),
#  ('Squad Fish', 7),
#  ('Pet Haunting', 8),
#  ('Records Zorro', 8),
#  ('Papi Necklace', 8),
#  ('Punk Divorce', 8),
#  ('Ali Forever', 9),
#  ('Frisco Forrest', 9),
#  ('Legally Secretary', 9),
#  ('Legend Jedi', 9),
#  ('Monsoon Cause', 9),
#  ('Won Dares', 9),
#  ('Crazy Home', 9),
#  ('Oleander Clue', 10),
#  ('Wagon Jaws', 10),
#  ('Superfly Trip', 10),
#  ('Sensibility Rear', 10),
#  ('Paths Control', 10),
#  ('Jawbreaker Brooklyn', 10),
# ...

# %%
#**16. Muestra las películas que se ofrecen para alquilar en store_id 1 y no se ofrecen en store_id 2. **

# %%
import psycopg2

# Connect to an existing database HEROKY _ nuestro nombre
conn = psycopg2.connect(
    host="ec2-54-73-58-75.eu-west-1.compute.amazonaws.com",
    database="d6jbvjn3b9tsce",
    user="mayknebhombpsq",
    password="dbc24635f5cbe1851f07d823eeada249c8751415ee900274b96110652bc94874",
    port=5432)

query = """
SELECT
  film.title
FROM
  (SELECT DISTINCT film_id FROM inventory WHERE store_id=1) AS film_store1
LEFT JOIN
  (SELECT DISTINCT film_id FROM inventory WHERE store_id=2) AS film_store2
ON
  film_store1.film_id = film_store2.film_id
LEFT JOIN
  film
ON
  film_store2.film_id = film.film_id
WHERE
  film_store2.film_id IS NULL
;
"""

#Creating a cursor object using the cursor() method
cursor = conn.cursor()
#Retrieving data
cursor.execute(query)
#Fetching 1st row from the table
#result = cursor.fetchone()
#print(result)
#Fetching 1st row from the table
result = cursor.fetchall()
print(result)
print(len(result))
# Out:
# [(None, None), (None, None), (None, None), (None, None), (None, None), (None, None), (None, None), (None, None), (None, None), (None, None), (None, None), (None, None), (None, None), (None, None), (None, None), (None, None), (None, None), (None, None), (None, None), (None, None), (None, None), (None, None), (None, None), (None, None), (None, None), (None, None), (None, None), (None, None), (None, None), (None, None), (None, None), (None, None), (None, None), (None, None), (None, None), (None, None), (None, None), (None, None), (None, None), (None, None), (None, None), (None, None), (None, None), (None, None), (None, None), (None, None), (None, None), (None, None), (None, None), (None, None), (None, None), (None, None), (None, None), (None, None), (None, None), (None, None), (None, None), (None, None), (None, None), (None, None), (None, None), (None, None), (None, None), (None, None), (None, None), (None, None), (None, None), (None, None), (None, None), (None, None), (None, None), (No
# ...

# %%
import psycopg2

# Connect to an existing database HEROKY _ nuestro nombre
conn = psycopg2.connect(
    host="ec2-54-73-58-75.eu-west-1.compute.amazonaws.com",
    database="d6jbvjn3b9tsce",
    user="mayknebhombpsq",
    password="dbc24635f5cbe1851f07d823eeada249c8751415ee900274b96110652bc94874",
    port=5432)

query = """
SELECT DISTINCT
film_id
FROM
inventory
WHERE store_id=1
EXCEPT
SELECT DISTINCT
film_id
FROM
inventory
WHERE
store_id=2

;
"""

#Creating a cursor object using the cursor() method
cursor = conn.cursor()
#Retrieving data
cursor.execute(query)
#Fetching 1st row from the table
#result = cursor.fetchone()
#print(result)
#Fetching 1st row from the table
result = cursor.fetchall()
print(result)
print(len(result))
# Out:
# [(652,), (550,), (394,), (272,), (867,), (539,), (278,), (929,), (919,), (529,), (888,), (940,), (390,), (261,), (876,), (161,), (632,), (587,), (120,), (815,), (695,), (766,), (29,), (96,), (466,), (201,), (400,), (219,), (241,), (66,), (661,), (340,), (523,), (699,), (368,), (152,), (548,), (787,), (886,), (750,), (182,), (528,), (110,), (27,), (811,), (853,), (84,), (996,), (799,), (276,), (983,), (375,), (682,), (674,), (401,), (153,), (279,), (543,), (736,), (565,), (566,), (259,), (965,), (840,), (30,), (927,), (774,), (984,), (296,), (209,), (868,), (205,), (947,), (978,), (407,), (904,), (783,), (540,), (168,), (598,), (393,), (498,), (277,), (290,), (793,), (342,), (360,), (224,), (719,), (53,), (933,), (136,), (442,), (411,), (825,), (899,), (675,), (885,), (969,), (185,), (653,), (435,), (617,), (765,), (732,), (959,), (819,), (817,), (364,), (299,), (971,), (836,), (197,), (470,), (454,), (482,), (577,), (188,), (561,), (196,), (291,), (81,), (721,), (705,), (427,), (347,
# ...

# %%
#**17. Muestre las películas que se ofrecen para alquilar en cualquiera de las dos tiendas 1 y 2.**

# %%
import psycopg2

# Connect to an existing database HEROKY _ nuestro nombre
conn = psycopg2.connect(
    host="ec2-54-73-58-75.eu-west-1.compute.amazonaws.com",
    database="d6jbvjn3b9tsce",
    user="mayknebhombpsq",
    password="dbc24635f5cbe1851f07d823eeada249c8751415ee900274b96110652bc94874",
    port=5432)

query = """
SELECT
  film.title
FROM
  (SELECT DISTINCT film_id FROM inventory WHERE store_id=1) AS film_store1
FULL JOIN
  (SELECT DISTINCT film_id FROM inventory WHERE store_id=2) AS film_store2
ON
  film_store1.film_id = film_store2.film_id
LEFT JOIN
  film
ON
  film_store2.film_id = film.film_id
;
"""

#Creating a cursor object using the cursor() method
cursor = conn.cursor()
#Retrieving data
cursor.execute(query)
#Fetching 1st row from the table
#result = cursor.fetchone()
#print(result)
#Fetching 1st row from the table
result = cursor.fetchall()
print(result)
print(len(result))
# Out:
# [('Academy Dinosaur',), ('Ace Goldfinger',), ('Adaptation Holes',), ('Affair Prejudice',), ('African Egg',), ('Agent Truman',), ('Airplane Sierra',), ('Airport Pollock',), ('Alabama Devil',), ('Aladdin Calendar',), ('Alamo Videotape',), ('Alaska Phantom',), ('Ali Forever',), ('Alien Center',), ('Alley Evolution',), ('Alone Trip',), ('Alter Victory',), ('Amadeus Holy',), (None,), ('American Circus',), ('Amistad Midsummer',), ('Anaconda Confessions',), (None,), ('Angels Life',), ('Annie Identity',), (None,), (None,), (None,), (None,), ('Apache Divine',), ('Apocalypse Flamingos',), ('Arabia Dogma',), ('Arachnophobia Rollercoaster',), ('Arizona Bang',), ('Armageddon Lost',), ('Army Flintstones',), ('Artist Coldblooded',), ('Atlantis Cause',), ('Attacks Hate',), ('Attraction Newton',), ('Autumn Crow',), ('Baby Hall',), ('Backlash Undefeated',), ('Badman Dawn',), ('Baked Cleopatra',), ('Balloon Homeward',), ('Ballroom Mockingbird',), (None,), ('Banger Pinocchio',), ('Barbarella Streetcar',
# ...

# %%
#**18. Muestra los títulos de las películas que se ofrecen en ambas tiendas al mismo tiempo**

# %%
import psycopg2

# Connect to an existing database HEROKY _ nuestro nombre
conn = psycopg2.connect(
    host="ec2-54-73-58-75.eu-west-1.compute.amazonaws.com",
    database="d6jbvjn3b9tsce",
    user="mayknebhombpsq",
    password="dbc24635f5cbe1851f07d823eeada249c8751415ee900274b96110652bc94874",
    port=5432)

query = """
SELECT
  film.title
FROM
  (SELECT DISTINCT film_id FROM inventory WHERE store_id=1) AS film_store1
JOIN
  (SELECT DISTINCT film_id FROM inventory WHERE store_id=2) AS film_store2
ON
  film_store1.film_id = film_store2.film_id
JOIN
  film
ON
  film_store2.film_id = film.film_id
;
"""

#Creating a cursor object using the cursor() method
cursor = conn.cursor()
#Retrieving data
cursor.execute(query)
#Fetching 1st row from the table
#result = cursor.fetchone()
#print(result)
#Fetching 1st row from the table
result = cursor.fetchall()
print(result)
print(len(result))
# Out:
# [('Academy Dinosaur',), ('Affair Prejudice',), ('Agent Truman',), ('Airplane Sierra',), ('Alabama Devil',), ('Aladdin Calendar',), ('Alamo Videotape',), ('Alaska Phantom',), ('Alien Center',), ('Alley Evolution',), ('Alone Trip',), ('Alter Victory',), ('Amadeus Holy',), ('American Circus',), ('Amistad Midsummer',), ('Anaconda Confessions',), ('Angels Life',), ('Annie Identity',), ('Apache Divine',), ('Arachnophobia Rollercoaster',), ('Arizona Bang',), ('Armageddon Lost',), ('Atlantis Cause',), ('Attacks Hate',), ('Attraction Newton',), ('Backlash Undefeated',), ('Badman Dawn',), ('Baked Cleopatra',), ('Balloon Homeward',), ('Banger Pinocchio',), ('Barbarella Streetcar',), ('Barefoot Manchurian',), ('Basic Easy',), ('Bear Graceland',), ('Beauty Grease',), ('Bedazzled Married',), ('Berets Agent',), ('Betrayed Rear',), ('Beverly Outlaw',), ('Bikini Borrowers',), ('Bill Others',), ('Bingo Talented',), ('Birch Antitrust',), ('Birds Perdition',), ('Blackout Private',), ('Blade Polish',), (
# ...

# %%
#**19. Para cada tienda, muestre el número de clientes que son miembros de esa tienda**

# %%
import psycopg2

# Connect to an existing database HEROKY _ nuestro nombre
conn = psycopg2.connect(
    host="ec2-54-73-58-75.eu-west-1.compute.amazonaws.com",
    database="d6jbvjn3b9tsce",
    user="mayknebhombpsq",
    password="dbc24635f5cbe1851f07d823eeada249c8751415ee900274b96110652bc94874",
    port=5432)

query = """
SELECT
  store_id, count(customer_id)
FROM
  customer
GROUP BY
  1;
"""

#Creating a cursor object using the cursor() method
cursor = conn.cursor()
#Retrieving data
cursor.execute(query)
#Fetching 1st row from the table
#result = cursor.fetchone()
#print(result)
#Fetching 1st row from the table
result = cursor.fetchall()
result
# Out:
# [(1, 326), (2, 273)]

# %%
#**20. Muestra el título de la película más alquilada en la tienda con store_id 1**

# %%
import psycopg2

# Connect to an existing database HEROKY _ nuestro nombre
conn = psycopg2.connect(
    host="ec2-54-73-58-75.eu-west-1.compute.amazonaws.com",
    database="d6jbvjn3b9tsce",
    user="mayknebhombpsq",
    password="dbc24635f5cbe1851f07d823eeada249c8751415ee900274b96110652bc94874",
    port=5432)

query = """
SELECT
  inventory.film_id, count(rental.rental_id)
FROM
  rental
JOIN
  inventory
ON
  inventory.inventory_id = rental.inventory_id
wHERE
  inventory.store_id = 1
GROUP BY
  inventory.film_id
ORDER BY 2 DESC
LIMIT 1
;
"""

#Creating a cursor object using the cursor() method
cursor = conn.cursor()
#Retrieving data
cursor.execute(query)
#Fetching 1st row from the table
#result = cursor.fetchone()
#print(result)
#Fetching 1st row from the table
result = cursor.fetchall()
result
# Out:
# [(535, 20)]

# %%
##**21. Cuántas películas aún no se ofrecen para alquilar en las tiendas. Hay dos tiendas solo 1 y 2**

# %%
import psycopg2

# Connect to an existing database HEROKY _ nuestro nombre
conn = psycopg2.connect(
    host="ec2-54-73-58-75.eu-west-1.compute.amazonaws.com",
    database="d6jbvjn3b9tsce",
    user="mayknebhombpsq",
    password="dbc24635f5cbe1851f07d823eeada249c8751415ee900274b96110652bc94874",
    port=5432)

query = """
SELECT
  film.title, inventory.store_id
FROM
  film
LEFT JOIN
  inventory
ON
  inventory.film_id = film.film_id
WHERE
  inventory.film_id IS NULL
;
"""

#Creating a cursor object using the cursor() method
cursor = conn.cursor()
#Retrieving data
cursor.execute(query)
#Fetching 1st row from the table
#result = cursor.fetchone()
#print(result)
#Fetching 1st row from the table
result = cursor.fetchall()
result
# Out:
# [('Alice Fantasia', None),
#  ('Apollo Teen', None),
#  ('Argonauts Town', None),
#  ('Ark Ridgemont', None),
#  ('Arsenic Independence', None),
#  ('Boondock Ballroom', None),
#  ('Butch Panther', None),
#  ('Catch Amistad', None),
#  ('Chinatown Gladiator', None),
#  ('Chocolate Duck', None),
#  ('Commandments Express', None),
#  ('Crossing Divorce', None),
#  ('Crowds Telemark', None),
#  ('Crystal Breaking', None),
#  ('Dazed Punk', None),
#  ('Deliverance Mulholland', None),
#  ('Firehouse Vietnam', None),
#  ('Floats Garden', None),
#  ('Frankenstein Stranger', None),
#  ('Gladiator Westward', None),
#  ('Gump Date', None),
#  ('Hate Handicap', None),
#  ('Hocus Frida', None),
#  ('Kentuckian Giant', None),
#  ('Kill Brotherhood', None),
#  ('Muppet Mile', None),
#  ('Order Betrayed', None),
#  ('Pearl Destiny', None),
#  ('Perdition Fargo', None),
#  ('Psycho Shrunk', None),
#  ('Raiders Antitrust', None),
#  ('Rainbow Shock', None),
#  ('Roof Champion', None),
# ...

# %%
##**22. Muestre los customer_id para aquellos clientes que alquilaron un DVD de películas más de una vez.**
#Para responder a esta pregunta, primero debemos conocer los film_ids que alquiló cada cliente.

# %%
import psycopg2

# Connect to an existing database HEROKY _ nuestro nombre
conn = psycopg2.connect(
    host="ec2-54-73-58-75.eu-west-1.compute.amazonaws.com",
    database="d6jbvjn3b9tsce",
    user="mayknebhombpsq",
    password="dbc24635f5cbe1851f07d823eeada249c8751415ee900274b96110652bc94874",
    port=5432)

query = """
SELECT
 rental.customer_id, inventory.film_id, COUNT(rental.rental_id)
FROM
  rental
JOIN
  inventory
ON
  inventory.inventory_id = rental.inventory_id
GROUP BY
  1,2
HAVING COUNT(rental.rental_id) > 1;
"""

#Creating a cursor object using the cursor() method
cursor = conn.cursor()
#Retrieving data
cursor.execute(query)
#Fetching 1st row from the table
#result = cursor.fetchone();
#print(result)
#Fetching 1st row from the table
result = cursor.fetchall();
print(result)
print(len(result))
# Out:
# [(513, 854, 2), (280, 911, 2), (245, 254, 2), (516, 646, 2), (562, 311, 2), (296, 838, 2), (260, 267, 2), (366, 307, 2), (468, 972, 2), (408, 373, 2), (287, 115, 2), (414, 800, 2), (47, 21, 2), (270, 756, 2), (64, 562, 2), (463, 140, 2), (391, 114, 2), (169, 172, 2), (278, 388, 2), (323, 303, 2), (594, 214, 2), (582, 625, 2), (142, 973, 2), (476, 78, 2), (46, 979, 2), (36, 462, 2), (495, 843, 2), (237, 63, 2), (72, 303, 2), (412, 915, 2), (47, 307, 2), (573, 12, 2), (403, 460, 2), (198, 966, 2), (6, 807, 2), (196, 326, 2), (356, 207, 2), (251, 972, 2), (122, 611, 2), (560, 84, 2), (244, 11, 2), (209, 381, 2), (440, 12, 2), (181, 103, 2), (234, 170, 2), (502, 434, 2), (372, 579, 2), (334, 689, 2), (249, 535, 2), (569, 753, 2), (56, 869, 2), (1, 663, 2), (557, 873, 2), (321, 893, 2), (18, 995, 2), (384, 143, 2), (132, 484, 2), (467, 141, 2), (452, 353, 2), (421, 521, 2), (74, 951, 2), (458, 942, 2), (137, 215, 2), (251, 445, 2), (464, 360, 2), (525, 86, 2), (526, 966, 2), (39, 738, 2),
# ...

# %%
#**23. Muestra la cantidad de películas alquiladas en cada clasificación.**
#Para responder a esta pregunta, primero debemos conocer los ID de película que se alquilaron (unir tablas de alquiler e inventario) y las calificaciones de cada película (unir tabla de películas).

# %%
import psycopg2

# Connect to an existing database HEROKY _ nuestro nombre
conn = psycopg2.connect(
    host="ec2-54-73-58-75.eu-west-1.compute.amazonaws.com",
    database="d6jbvjn3b9tsce",
    user="mayknebhombpsq",
    password="dbc24635f5cbe1851f07d823eeada249c8751415ee900274b96110652bc94874",
    port=5432)

query = """
SELECT
 film.rating, COUNT (rental.rental_date)
FROM
  film
FULL JOIN
  inventory
ON
  film.film_id = inventory.film_id
FULL JOIN
  rental
ON
  rental.inventory_id = inventory.inventory_id
WHERE
  rental.rental_date IS NOT NULL
GROUP BY
  1
;
"""

#Creating a cursor object using the cursor() method
cursor = conn.cursor()
#Retrieving data
cursor.execute(query)
#Fetching 1st row from the table
#result = cursor.fetchone();
#print(result)
#Fetching 1st row from the table
result = cursor.fetchall()
result
# Out:
# [('G', 2773), ('R', 3181), ('NC-17', 3293), ('PG', 3212), ('PG-13', 3585)]

# %%
#Si en lugar de calcular la cantidad de alquileres por categoría calculo la cantidad de películas por categoría:

# %%
import psycopg2

# Connect to an existing database HEROKY _ nuestro nombre
conn = psycopg2.connect(
    host="ec2-54-73-58-75.eu-west-1.compute.amazonaws.com",
    database="d6jbvjn3b9tsce",
    user="mayknebhombpsq",
    password="dbc24635f5cbe1851f07d823eeada249c8751415ee900274b96110652bc94874",
    port=5432)

query = """
SELECT
 film.rating, COUNT (DISTINCT film.title)
FROM
  film
FULL JOIN
  inventory
ON
  film.film_id = inventory.film_id
FULL JOIN
  rental
ON
  rental.inventory_id = inventory.inventory_id
WHERE
  rental.rental_date IS NOT NULL
GROUP BY
  1
;
"""

#Creating a cursor object using the cursor() method
cursor = conn.cursor()
#Retrieving data
cursor.execute(query)
#Fetching 1st row from the table
#result = cursor.fetchone();
#print(result)
#Fetching 1st row from the table
result = cursor.fetchall()
result
# Out:
# [('G', 171), ('PG', 183), ('PG-13', 213), ('R', 189), ('NC-17', 202)]

# %%
import psycopg2

# Connect to an existing database HEROKY _ nuestro nombre
conn = psycopg2.connect(
    host="ec2-54-73-58-75.eu-west-1.compute.amazonaws.com",
    database="d6jbvjn3b9tsce",
    user="mayknebhombpsq",
    password="dbc24635f5cbe1851f07d823eeada249c8751415ee900274b96110652bc94874",
    port=5432)

query = """
select count (distinct film.film_id)
from film
;
"""

#Creating a cursor object using the cursor() method
cursor = conn.cursor()
#Retrieving data
cursor.execute(query)
#Fetching 1st row from the table
#result = cursor.fetchone();
#print(result)
#Fetching 1st row from the table
result = cursor.fetchall()
result
# Out:
# [(1000,)]

# %%
# Out:
# [('Academy Dinosaur',),
#  ('Alice Fantasia',),
#  ('Apollo Teen',),
#  ('Argonauts Town',),
#  ('Ark Ridgemont',),
#  ('Arsenic Independence',),
#  ('Boondock Ballroom',),
#  ('Butch Panther',),
#  ('Catch Amistad',),
#  ('Chinatown Gladiator',),
#  ('Chocolate Duck',),
#  ('Commandments Express',),
#  ('Crossing Divorce',),
#  ('Crowds Telemark',),
#  ('Crystal Breaking',),
#  ('Dazed Punk',),
#  ('Deliverance Mulholland',),
#  ('Firehouse Vietnam',),
#  ('Floats Garden',),
#  ('Frankenstein Stranger',),
#  ('Gladiator Westward',),
#  ('Gump Date',),
#  ('Hate Handicap',),
#  ('Hocus Frida',),
#  ('Kentuckian Giant',),
#  ('Kill Brotherhood',),
#  ('Muppet Mile',),
#  ('Order Betrayed',),
#  ('Pearl Destiny',),
#  ('Perdition Fargo',),
#  ('Psycho Shrunk',),
#  ('Raiders Antitrust',),
#  ('Rainbow Shock',),
#  ('Roof Champion',),
#  ('Sister Freddy',),
#  ('Sky Miracle',),
#  ('Suicides Silence',),
#  ('Tadpole Park',),
#  ('Treasure Command',),
#  ('Villain Desperate',),
# ...

# %%
#**24. Muestre el beneficio de cada una de las tiendas 1 y 2.**
#Para responder a esta pregunta, necesitamos saber la cantidad pagada y el Inventory_id para cada película alquilada al unirse (tablas de alquiler y pago) y el store_id para esa transacción de alquiler (unirse a la tabla de inventario).

# %%
import psycopg2

# Connect to an existing database HEROKY _ nuestro nombre
conn = psycopg2.connect(
    host="ec2-54-73-58-75.eu-west-1.compute.amazonaws.com",
    database="d6jbvjn3b9tsce",
    user="mayknebhombpsq",
    password="dbc24635f5cbe1851f07d823eeada249c8751415ee900274b96110652bc94874",
    port=5432)

query = """
select inventory.store_id, SUM(payment.amount)
FROM
payment
JOIN
rental
ON
payment.rental_id = rental.rental_id
JOIN
inventory
ON
inventory.inventory_id = rental.inventory_id
GROUP BY
store_id
;
"""

#Creating a cursor object using the cursor() method
cursor = conn.cursor()
#Retrieving data
cursor.execute(query)
#Fetching 1st row from the table
#result = cursor.fetchone();
#print(result)
#Fetching 1st row from the table
result = cursor.fetchall()
result
# Out:
# [(1, Decimal('30628.91')), (2, Decimal('30683.13'))]

# %%
#**25.  Muestra el beneficio de cada una de las tiendas 1 y 2 seguido del beneficio total de ambas tiendas**

# %%
import psycopg2

# Connect to an existing database HEROKY _ nuestro nombre
conn = psycopg2.connect(
    host="ec2-54-73-58-75.eu-west-1.compute.amazonaws.com",
    database="d6jbvjn3b9tsce",
    user="mayknebhombpsq",
    password="dbc24635f5cbe1851f07d823eeada249c8751415ee900274b96110652bc94874",
    port=5432)

query = """
select inventory.store_id, SUM(payment.amount)
FROM
payment
JOIN
rental
ON
payment.rental_id = rental.rental_id
JOIN
inventory
ON
inventory.inventory_id = rental.inventory_id
GROUP BY
store_id
;
"""

#Creating a cursor object using the cursor() method
cursor = conn.cursor()
#Retrieving data
cursor.execute(query)
#Fetching 1st row from the table
#result = cursor.fetchone();
#print(result)
#Fetching 1st row from the table
result = cursor.fetchall()
print(result)

query = """
select SUM(payment.amount)
FROM
payment

;
"""

#Creating a cursor object using the cursor() method
cursor = conn.cursor()
#Retrieving data
cursor.execute(query)
#Fetching 1st row from the table
#result = cursor.fetchone();
#print(result)
#Fetching 1st row from the table
result = cursor.fetchall()
print(result)
# Out:
# [(1, Decimal('30628.91')), (2, Decimal('30683.13'))]
# [(Decimal('61312.04'),)]

# %%
#**26. Cuente la cantidad de actores cuyos nombres no comienzan con una "A"**

# %%
import psycopg2

# Connect to an existing database HEROKY _ nuestro nombre
conn = psycopg2.connect(
    host="ec2-54-73-58-75.eu-west-1.compute.amazonaws.com",
    database="d6jbvjn3b9tsce",
    user="mayknebhombpsq",
    password="dbc24635f5cbe1851f07d823eeada249c8751415ee900274b96110652bc94874",
    port=5432)

query = """
SELECT
 count(actor_id)
FROM
  actor
WHERE
  first_name LIKE 'A%';
"""

#Creating a cursor object using the cursor() method
cursor = conn.cursor()
#Retrieving data
cursor.execute(query)
#Fetching 1st row from the table
#result = cursor.fetchone();
#print(result)
#Fetching 1st row from the table
result = cursor.fetchall();
result
# Out:
# [(13,)]

# %%
#**27. Busque el nombre del actor que comience con "P" seguido de (una *e* o una *a*) y luego cualquier otra letra**

# %%
import psycopg2

# Connect to an existing database HEROKY _ nuestro nombre
conn = psycopg2.connect(
    host="ec2-54-73-58-75.eu-west-1.compute.amazonaws.com",
    database="d6jbvjn3b9tsce",
    user="mayknebhombpsq",
    password="dbc24635f5cbe1851f07d823eeada249c8751415ee900274b96110652bc94874",
    port=5432)

query = """
SELECT DISTINCT
  first_name
FROM
  actor
WHERE
  first_name LIKE 'Pe%' or first_name LIKE 'Pa%';
"""

#Creating a cursor object using the cursor() method
cursor = conn.cursor()
#Retrieving data
cursor.execute(query)
#Fetching 1st row from the table
#result = cursor.fetchone();
#print(result)
#Fetching 1st row from the table
result = cursor.fetchall();
result
# Out:
# [('Parker',), ('Penelope',)]

# %%
#**28. Busque nombres de clientes que comiencen con "P" seguido de 5 letras**

# %%
import psycopg2

# Connect to an existing database HEROKY _ nuestro nombre
conn = psycopg2.connect(
    host="ec2-54-73-58-75.eu-west-1.compute.amazonaws.com",
    database="d6jbvjn3b9tsce",
    user="mayknebhombpsq",
    password="dbc24635f5cbe1851f07d823eeada249c8751415ee900274b96110652bc94874",
    port=5432)

query = """
SELECT
 first_name
FROM
  actor
WHERE
  first_name LIKE 'P_____';
"""

#Creating a cursor object using the cursor() method
cursor = conn.cursor()
#Retrieving data
cursor.execute(query)
#Fetching 1st row from the table
#result = cursor.fetchone();
#print(result)
#Fetching 1st row from the table
result = cursor.fetchall();
result
# Out:
# [('Parker',)]

# %%
#**29. Busque actores con PaRkEr como su nombre e ignore las letras mayúsculas y minúsculas. Luego seleccione actores llamados PaRkEr y haga coincidir el caso de la letra**

# %%
import psycopg2

# Connect to an existing database HEROKY _ nuestro nombre
conn = psycopg2.connect(
    host="ec2-54-73-58-75.eu-west-1.compute.amazonaws.com",
    database="d6jbvjn3b9tsce",
    user="mayknebhombpsq",
    password="dbc24635f5cbe1851f07d823eeada249c8751415ee900274b96110652bc94874",
    port=5432)

query = """
SELECT
 first_name
FROM
  actor
WHERE
  first_name ~* 'PaRkEr';
"""

#Creating a cursor object using the cursor() method
cursor = conn.cursor()
#Retrieving data
cursor.execute(query)
#Fetching 1st row from the table
#result = cursor.fetchone();
#print(result)
#Fetching 1st row from the table
result = cursor.fetchall();
result
# Out:
# [('Parker',)]

# %%
#**30. Busque nombres de actores que comiencen con "P" seguidos de cualquier letra de la a a la e y luego de cualquier otra letra**

# %%
import psycopg2

# Connect to an existing database HEROKY _ nuestro nombre
conn = psycopg2.connect(
    host="ec2-54-73-58-75.eu-west-1.compute.amazonaws.com",
    database="d6jbvjn3b9tsce",
    user="mayknebhombpsq",
    password="dbc24635f5cbe1851f07d823eeada249c8751415ee900274b96110652bc94874",
    port=5432)

query = """
SELECT
 first_name
FROM
  actor
WHERE
  first_name SIMILAR TO 'P(a|b|c|c|e)%';
"""

#Creating a cursor object using the cursor() method
cursor = conn.cursor()
#Retrieving data
cursor.execute(query)
#Fetching 1st row from the table
#result = cursor.fetchone();
#print(result)
#Fetching 1st row from the table
result = cursor.fetchall();
result
# Out:
# [('Penelope',), ('Parker',), ('Penelope',), ('Penelope',), ('Penelope',)]
