# %% [markdown]
# # Programación 201

# %% [markdown]
# Librerías científicas en Python: `Pandas`
# ------------------------------------------------------

# %% [markdown]
# ### Ejercicio 1
#
# Cargad los datos del fichero _got.csv_ en un _dataframe_. Este conjunto de datos recoge información de la [Guerra de los Cinco Reyes](https://awoiaf.westeros.org/index.php/War_of_the_Five_Kings) de las novelas de [Cancion de Hielo y Fuego](https://es.wikipedia.org/wiki/Canci%C3%B3n_de_hielo_y_fuego) de George R.R Martin.
#
# Mostrad el número de filas del _dataframe_ y las etiquetas de los ejes.

# %%
import numpy as np
import pandas as pd
df = pd.read_csv('/content/got.csv')

# %%
filas = df.shape[0]

# %%
df.shape
# Out:
# (38, 25)

# %%
df.columns
# Out:
# Index(['name', 'year', 'battle_number', 'attacker_king', 'defender_king',
#        'attacker_1', 'attacker_2', 'attacker_3', 'attacker_4', 'defender_1',
#        'defender_2', 'defender_3', 'defender_4', 'attacker_outcome',
#        'battle_type', 'major_death', 'major_capture', 'attacker_size',
#        'defender_size', 'attacker_commander', 'defender_commander', 'summer',
#        'location', 'region', 'note'],
#       dtype='object')

# %%
df.head()
# Out:
#                             name  year  ...           region note
# 0     Battle of the Golden Tooth   298  ...  The Westerlands  NaN
# 1    Battle at the Mummer's Ford   298  ...   The Riverlands  NaN
# 2             Battle of Riverrun   298  ...   The Riverlands  NaN
# 3       Battle of the Green Fork   298  ...   The Riverlands  NaN
# 4  Battle of the Whispering Wood   298  ...   The Riverlands  NaN
#
# [5 rows x 25 columns]

# %% [markdown]
# ### Ejercicio 2
#
# Agrupad los datos cargados en el ejercicio 1 por el principal bando atacante (*attacker\_1*). Para cada posición, mostrad el número de batallas y el resultado de la batalla (el resultado se encuentra en el campo *attacker\_outcome*).

# %%
df_agrupado = df.groupby(['attacker_1','attacker_outcome']).count().iloc[:,2]
df_agrupado
# Out:
# attacker_1                   attacker_outcome
# Baratheon                    loss                1
#                              win                 4
# Bolton                       win                 2
# Bracken                      win                 1
# Brave Companions             win                 1
# Brotherhood without Banners  win                 1
# Darry                        win                 1
# Free folk                    loss                1
# Frey                         win                 2
# Greyjoy                      win                 7
# Lannister                    loss                1
#                              win                 7
# Stark                        loss                2
#                              win                 6
# Name: battle_number, dtype: int64

# %% [markdown]
# ### Ejercicio 3
#
# Mostrad los datos de las batallas donde el numero de participantes supera los 15000 "hombres" (contando ambos bandos: *attacker\_size* y *defender\_size*), el resultado haya sido favorable para el atacante, y la batalla se haya producido en invierno (_summer=0_).

# %%
df[(df['attacker_size']+df['defender_size']>15000) & (df['attacker_outcome']=='win') & (df['summer'] == 0.0)]
# Out:
# Empty DataFrame
# Columns: [name, year, battle_number, attacker_king, defender_king, attacker_1, attacker_2, attacker_3, attacker_4, defender_1, defender_2, defender_3, defender_4, attacker_outcome, battle_type, major_death, major_capture, attacker_size, defender_size, attacker_commander, defender_commander, summer, location, region, note]
# Index: []

# %%
#df['attacker_size'] = df['attacker_size'].fillna(0)
#df['defender_size'] = df['defender_size'].fillna(0)
#DUDA: ¿Podría reemplazar en una sola instrucción todos los nulos de ambas columnas?

df['attacker_size'] = df['attacker_size'].replace(np.nan, 0)
df['defender_size'] = df['defender_size'].replace(np.nan, 0)
df[(df['attacker_size']+df['defender_size']>15000) & (df['attacker_outcome']=='win') & (df['summer'] == 0.0)]
# Out:
# Empty DataFrame
# Columns: [name, year, battle_number, attacker_king, defender_king, attacker_1, attacker_2, attacker_3, attacker_4, defender_1, defender_2, defender_3, defender_4, attacker_outcome, battle_type, major_death, major_capture, attacker_size, defender_size, attacker_commander, defender_commander, summer, location, region, note]
# Index: []

# %% [markdown]
# ### Ejercicio 4
#
# Contad el número de lugares que aparecen más de una vez en _dataframe_ (campo _location_), utilizando las funciones de la librería _pandas_. ¿Existe algún lugar donde se haya realizado más de una batalla? Comprobad qué bandos estaban implicados.

# %%
#df_agrupado = df.groupby(['location']).count().iloc[:,2:13]
#df_agrupado = df.groupby(['location']).count().iloc[:,2:13]
df_agrupado_location = df.groupby(['location']).count().iloc[:,2]
sr = df_agrupado_location[(df_agrupado_location[:]>1)]
print(sr)
indexes = sr.index
columnas =['location','attacker_king', 'defender_king',
       'attacker_1', 'attacker_2', 'attacker_3', 'attacker_4', 'defender_1',
       'defender_2', 'defender_3', 'defender_4']
df[columnas].loc[df.location.isin(indexes)].iloc[:].sort_values('location')
# Out:
# location
# Darry               2
# Deepwood Motte      2
# Harrenhal           2
# Moat Cailin         2
# Riverrun            3
# Storm's End         2
# Torrhen's Square    2
# Winterfell          3
# Name: battle_number, dtype: int64
#             location             attacker_king  ... defender_3 defender_4
# 6              Darry  Joffrey/Tommen Baratheon  ...        NaN        NaN
# 20             Darry                Robb Stark  ...        NaN        NaN
# 8     Deepwood Motte       Balon/Euron Greyjoy  ...        NaN        NaN
# 30    Deepwood Motte         Stannis Baratheon  ...        NaN        NaN
# 17         Harrenhal                Robb Stark  ...        NaN        NaN
# 24         Harrenhal  Joffrey/Tommen Baratheon  ...        NaN        NaN
# 7        Moat Cailin       Balon/Euron Greyjoy  ...        NaN        NaN
# 28       Moat Cailin  Joffrey/Tommen Baratheon  ...        NaN        NaN
# 2           Riverrun  Joffrey/Tommen Baratheon  ...        NaN        NaN
# 5           Riverrun                Robb Stark  ...        NaN        NaN
# 35          Riverrun  Joffrey/Tommen Baratheon  ...        NaN        NaN
# 33       Storm's End  Joffrey/Tommen Baratheon  ...        NaN        NaN
# 15       Storm's End         Stannis Baratheon  ...        NaN        NaN
# 10  Torrhen's Square                Robb Stark  ...        NaN        NaN
# 12  Torrhen's Square       Balon/Euron Greyjoy  ...        NaN        NaN
# 13        Winterfell  Joffrey/Tommen Baratheon  ...        NaN        NaN
# 11        Winterfell       Balon/Euron Greyjoy  ...        NaN        NaN
# 37        Winterfell         Stannis Baratheon  ...        NaN        NaN
#
# [18 rows x 11 columns]

# %% [markdown]
# ### Ejercicio 5
#
# Añadid una nueva columna al _dataframe_ con un valor booleano indicando una predicción básica de si en una cierta batalla el bando atacante será vencedor. Definiremos el valor como _True_ sí el bando atacante es mayor al defensor, y como _False_ en caso contrario. Definid como _NaN_ aquellos casos en los que no haya número de tropas en ningún bando. ¿En que casos, identificados por el número de batalla (*battle\_number*), nuestra predicción coincide con el resultado real?

# %%
df_prediccion = df.assign(prediccion=lambda x: x.attacker_size > x.defender_size)
df_prediccion.loc[(df_prediccion['attacker_size'] == 0) & (df_prediccion['defender_size'] == 0), 'prediccion'] = 'NaN'


#DUDA: Intento hacer un lambda condicional pero me da error:
#df_prediccion = df.assign(prediccion=lambda x: x.attacker_size > x.defender_size if x.attacker_size != 0 & x.defender_size!=0 else 'NaN')
df_prediccion
# Out:
#                                                  name  ...  prediccion
# 0                          Battle of the Golden Tooth  ...        True
# 1                         Battle at the Mummer's Ford  ...       False
# 2                                  Battle of Riverrun  ...        True
# 3                            Battle of the Green Fork  ...       False
# 4                       Battle of the Whispering Wood  ...       False
# 5                                 Battle of the Camps  ...       False
# 6                                       Sack of Darry  ...         NaN
# 7                               Battle of Moat Cailin  ...         NaN
# 8                            Battle of Deepwood Motte  ...        True
# 9                           Battle of the Stony Shore  ...        True
# 10                         Battle of Torrhen's Square  ...       False
# 11                               Battle of Winterfell  ...        True
# 12                           Sack of Torrhen's Square  ...         NaN
# 13                                 Sack of Winterfell  ...       False
# 14                                  Battle of Oxcross  ...       False
# 15                               Siege of Storm's End  ...       False
# 16                                Battle of the Fords  ...        True
# 17                                  Sack of Harrenhal  ...       False
# 18                                 Battle of the Crag  ...        True
# 19                           Battle of the Blackwater  ...        True
# 20                                     Siege of Darry  ...         NaN
# 21                               Battle of Duskendale  ...        True
# 22                       Battle of the Burning Septry  ...         NaN
# 23                            Battle of the Ruby Ford  ...       False
# 24                              Retaking of Harrenhal  ...         NaN
# 25                                    The Red Wedding  ...       False
# 26                                   Siege of Seagard  ...         NaN
# 27                             Battle of Castle Black  ...        True
# 28                                Fall of Moat Cailin  ...         NaN
# 29                                   Sack of Saltpans  ...         NaN
# 30                         Retaking of Deepwood Motte  ...        True
# 31                       Battle of the Shield Islands  ...         NaN
# 32  Invasion of Ryamsport, Vinetown, and Starfish ...  ...         NaN
# 33                        Second Seige of Storm's End  ...       False
# 34                               Siege of Dragonstone  ...        True
# 35                                  Siege of Riverrun  ...        True
# 36                                 Siege of Raventree  ...        True
# 37                                Siege of Winterfell  ...       False
#
# [38 rows x 26 columns]
